# %%
from IPython.display import display

# %%
import pandas as pd

# %%
table = pd.read_excel("Market_Status_Info_Report_2025-01-23.xlsx")
display(table)
# Out:
#                 Market         Type Start Scout   End Scout     Status
# 0        Knoxville, TN        Metro  2025-01-29  2025-02-03  Scheduled  \
# 1            Provo, UT        Metro  2025-01-26  2025-01-31  Scheduled
# 2        Allentown, PA        Metro  2025-01-26  2025-01-31  Scheduled
# 3            Omaha, NE        Metro  2025-01-26  2025-01-31  Scheduled
# 4       Fort Myers, FL        Metro  2025-01-26  2025-01-31  Scheduled
# 5               Nevada  State Route  2025-01-25  2025-01-29  Scheduled
# 6             Reno, NV        Metro  2025-01-25  2025-01-30  Scheduled
# 7        Lancaster, PA        Metro  2025-01-25  2025-01-30  Scheduled
# 8         McKinney, TX        Metro  2025-01-24  2025-01-29  Scheduled
# 9     Jacksonville, FL        Metro  2025-01-24  2025-02-01  Scheduled
# 10        Stockton, CA        Metro  2025-01-23  2025-01-28   Scouting
# 11  Corpus Christi, TX        Metro  2025-01-23  2025-01-28   Scouting
# ...
